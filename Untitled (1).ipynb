# %%
import seaborn as sns
from urllib.request import urlopen
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support import expected_conditions as ec
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
import unittest
import selenium.common.exceptions 
import time
import requests
import glob
from webdriver_manager.chrome import ChromeDriverManager
from fake_useragent import UserAgent
from selenium.webdriver.chrome.service import Service





def work():

    option = webdriver.ChromeOptions()
    #option.add_argument('--proxy-server="11.456.448.110:8080"')
    ua = UserAgent()
    userAgent = ua.random
    print(userAgent)
    option.add_argument(f'user-agent={userAgent}')
    #option.headless = True
    option.add_argument("--incognito")
    option.add_argument("--window-size=1920,1080")
    #option.add_argument('log-level=3')
    #prefs = {"download.default_directory" : "F:\\Documents\\DataPipeline\\Data\\Output\\imports"}
    #option.add_experimental_option("prefs",prefs)
    service = Service(executable_path=ChromeDriverManager().install())
    driver = webdriver.Chrome(service = service, options = option)
    driver.set_window_size(1920,1080)
    url = "https://www.google.com/search?q=hari+sure&oq=hari+sure&aqs=chrome..69i57j69i59l2j69i65.1568j0j1&sourceid=chrome&ie=UTF-8"
    driver.get(url)
    elements = driver.find_elements(By.TAG_NAME, 'a')
    #class="LC20lb MBeuO DKV0Md"
    """elements[1].click()
    time.sleep(2)
    driver.close() """
    for e in elements:
        #print(e.text)
        if "linkedin" in e.text:
            print("Here "+e.text)
            e.click()
            time.sleep(5)
            break
    print("Done")
i = 500
while i > 0:
    work()
    print(i)
    i-=1
# Out:
# Error occurred during loading data. Trying to use cache server https://fake-useragent.herokuapp.com/browsers/0.1.11
# Traceback (most recent call last):
#   File "C:\Users\smopuru\Anaconda3\lib\site-packages\fake_useragent\utils.py", line 154, in load
#     for item in get_browsers(verify_ssl=verify_ssl):
#   File "C:\Users\smopuru\Anaconda3\lib\site-packages\fake_useragent\utils.py", line 99, in get_browsers
#     html = html.split('<table class="w3-table-all notranslate">')[1]
# IndexError: list index out of range
# Mozilla/5.0 (Windows NT 6.4; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2225.0 Safari/537.36
#
# Here 5 "Hari Sure" profiles - LinkedIn
# www.linkedin.com › pub › dir › Hari › Sure
# Done
# 500
# Mozilla/5.0 (compatible, MSIE 11, Windows NT 6.3; Trident/7.0;  rv:11.0) like Gecko
#
# Here 5 "Hari Sure" profiles - LinkedIn
# www.linkedin.com › pub › dir › Hari › Sure
# Done
# 499
# ...

# %%
pip install proxy
# Out:
# ...
#
# ...
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
